# %%
''' 

                                                                    *C01P13 - Integer prime factorization
                                                                    
Given an integer n, we can factor it in the following form:

n = p1^a1 * p2^a2 * ... * pn^an
Where each p is a prime number and each a is an integer and p^a means p to the power of a.

This is called prime factorization

Lets see few examples:

10 = 2^1 * 5^1
25 = 5^2
356 = 2^2 * 89 ^ 1
Implement a function, called prime_factorization, which takes an integer and returns a list of tuples (pi, ai) that is the result of the factorization.

The list should be sorted in increasing order of the prime numbers.

Signature

def prime_factorization(n):
    pass
Examples

prime_factorization(10) == [(2, 1), (5, 1)] # This is 2^1 * 5^1
prime_factorization(14) == [(2, 1), (7, 1)]
prime_factorization(356) == [(2, 2), (89, 1)]
prime_factorization(89) == [(89, 1)] # 89 is a prime number
prime_factorization(1000) == [(2, 3), (5, 3)]                                                                    

'''

# %%
def is_prime(n):
    start = 2
    is_prime = True

    while start < n:
        if n % start == 0:
            is_prime = False
            break

        start += 1

    return is_prime


def new_fun(n):
   
    counter = 2
    numbers = [2]
    prime_numbers = []
    sum = int(n)
    iter = 1

    while counter < n:
        counter += 1
        numbers.append(int(counter))

    for number in numbers:
        if is_prime(number):
            prime_numbers.append(number)

    print(prime_numbers)
        


    while sum >= 0:
        
        if sum >= 0:
            print('while loop')
            for p in prime_numbers:
                print('for loop')
                if p <= sum:
                    
                    sum -= p
                    print('Sum = {}, and current Prime is {}'.format(sum, p))
       
                


new_fun(100)

# %%
def is_prime(n):
    start = 2
    is_prime = True

    while start < n:
        if n % start == 0:
            is_prime = False
            break

        start += 1

    return is_prime


def new_fun(n):
   
    counter = 2
    numbers = [2]
    prime_numbers = []
    sum = int(n)
    iter = 1
    flag_limit = True

    while counter < n:
        counter += 1
        numbers.append(int(counter))

    for number in numbers:
        if is_prime(number):
            prime_numbers.append(number)
    
    
    r_prime_numbers = prime_numbers.reverse()

    print(prime_numbers)
        


    while sum >= 0 and flag_limit is True:
        if sum <=0:
            flag_limit = False
            break
            
   
    for p in r_prime_numbers:
        if p <= sum:
            # for q in prime_numbers
                    
            sum -= p
            if sum <=0:
                flag_limit = False
                # print('Sum = {}, and current Prime is {}'.format(sum, p))
       
    if sum <= 0:
        return sum  

    
new_fun(100)
# Out:
# [97, 89, 83, 79, 73, 71, 67, 61, 59, 53, 47, 43, 41, 37, 31, 29, 23, 19, 17, 13, 11, 7, 5, 3, 2]

# %%
def is_prime(n):
    start = 2
    is_prime = True

    while start < n:
        if n % start == 0:
            is_prime = False
            break

        start += 1

    return is_prime


def goldbach(n):
   
    counter = 2
    numbers = [2]
    prime_numbers = []
    sum = int(n)
    iter = 1
    flag_limit = True

    while counter < n:
        counter += 1
        numbers.append(int(counter))

    for number in numbers:
        if is_prime(number):
            prime_numbers.append(number)
    
    
    r_prime_numbers = prime_numbers.reverse()

    print(prime_numbers)
        

    
    result = []
    nested_set  = {(0,0)}
   
    for p in prime_numbers:
        for q in prime_numbers:
            if p + q == n:
                # nested_set.add((p,q))
                result+= [(q,p)]
                print(result)

    if len(result) % 2 == 0:
        mid_range = int(len(result)/2)
        final_result = result[0:mid_range]
        return final_result
    
    elif len(result) == 1:
        mid_range = 1
        final_result = result[0:mid_range]
        return final_result

    else:
        mid_range = int(len(result)/2)+1
        final_result = result[0:mid_range]
        return final_result

                
   
                
                  
        
    
tests = [
    (4, [(2, 2)]),
    (6, [(3, 3)]),
    (8, [(3, 5)]),
    (10, [(3, 7), (5, 5)]),
    (100, [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53)])
]

for n, expected in tests:
    result = goldbach(n)

    print(result == expected)
# Out:
# [3, 2]
# [(2, 2)]
# True
# [5, 3, 2]
# [(3, 3)]
# True
# [7, 5, 3, 2]
# [(3, 5)]
# [(3, 5), (5, 3)]
# True
# [7, 5, 3, 2]
# [(3, 7)]
# [(3, 7), (5, 5)]
# [(3, 7), (5, 5), (7, 3)]
# True
# [97, 89, 83, 79, 73, 71, 67, 61, 59, 53, 47, 43, 41, 37, 31, 29, 23, 19, 17, 13, 11, 7, 5, 3, 2]
# [(3, 97)]
# [(3, 97), (11, 89)]
# [(3, 97), (11, 89), (17, 83)]
# [(3, 97), (11, 89), (17, 83), (29, 71)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53), (53, 47)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53), (53, 47), (59, 41)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53), (53, 47), (59, 41), (71, 29)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53), (53, 47), (59, 41), (71, 29), (83, 17)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53), (53, 47), (59, 41), (71, 29), (83, 17), (89, 11)]
# [(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53), (53, 47), (59, 41), (71, 29), (83, 17), (89, 11), (97, 3)]
# True

# %%
[(3, 97), (11, 89), (17, 83), (29, 71), (41, 59), (47, 53)]
